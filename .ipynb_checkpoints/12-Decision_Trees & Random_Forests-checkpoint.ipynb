# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
df=pd.read_csv('kyphosis.csv')

# %%
df.head()
# Out:
#   Kyphosis  Age  Number  Start
# 0   absent   71       3      5
# 1   absent  158       3     14
# 2  present  128       4      5
# 3   absent    2       5      1
# 4   absent    1       4     15

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Kyphosis  81 non-null     object
#  1   Age       81 non-null     int64
#  2   Number    81 non-null     int64
#  3   Start     81 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 2.7+ KB

# %%
sns.pairplot(df,hue='Kyphosis',kind='hist')

# %%
from sklearn.model_selection import train_test_split

# %%
X=df.drop('Kyphosis',axis=1)

# %%
y=df['Kyphosis']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree=DecisionTreeClassifier()

# %%
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
predictions=dtree.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(confusion_matrix(y_test,predictions))
print('\n')
print(classification_report(y_test,predictions))
# Out:
# [[18  5]
#  [ 2  0]]
#
#
#               precision    recall  f1-score   support
#
#       absent       0.90      0.78      0.84        23
#      present       0.00      0.00      0.00         2
#
#     accuracy                           0.72        25
#    macro avg       0.45      0.39      0.42        25
# weighted avg       0.83      0.72      0.77        25

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc=RandomForestClassifier(n_estimators=200)

# %%
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=200)

# %%
rfc_pred=rfc.predict(X_test)

# %%
print(confusion_matrix(y_test,rfc_pred))
print('\n')
print(classification_report(y_test,rfc_pred))
# Out:
# [[18  5]
#  [ 2  0]]
#
#
#               precision    recall  f1-score   support
#
#       absent       0.90      0.78      0.84        23
#      present       0.00      0.00      0.00         2
#
#     accuracy                           0.72        25
#    macro avg       0.45      0.39      0.42        25
# weighted avg       0.83      0.72      0.77        25

# %%
df['Kyphosis']
# Out:
# 0      absent
# 1      absent
# 2     present
# 3      absent
# 4      absent
#        ...
# 76    present
# 77     absent
# 78     absent
# 79    present
# 80     absent
# Name: Kyphosis, Length: 81, dtype: object

# %%
df['Kyphosis'].value_counts()
# Out:
# absent     64
# present    17
# Name: Kyphosis, dtype: int64

# %%
from io import StringIO

# %%
from IPython.display import Image  
from io import StringIO  
from sklearn.tree import export_graphviz
import pydot 

features = list(df.columns[1:])
features
# Out:
# ['Age', 'Number', 'Start']

# %%
dot_data = StringIO()  
export_graphviz(dtree, out_file=dot_data,feature_names=features,filled=True,rounded=True)

graph = pydot.graph_from_dot_data(dot_data.getvalue())  
Image(graph[0].create_png())

# %%
from sklearn import tree

# %%
plt.figure(figsize=(15,12))
tree.plot_tree(dtree,filled=True,fontsize=9,feature_names=X_train.columns,class_names=['absent','present'])
# Out:
# [Text(0.39285714285714285, 0.9, 'Start <= 8.5\ngini = 0.392\nsamples = 56\nvalue = [41, 15]\nclass = absent'),
#  Text(0.14285714285714285, 0.7, 'Age <= 11.5\ngini = 0.391\nsamples = 15\nvalue = [4, 11]\nclass = present'),
#  Text(0.07142857142857142, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = absent'),
#  Text(0.21428571428571427, 0.5, 'Age <= 130.5\ngini = 0.26\nsamples = 13\nvalue = [2, 11]\nclass = present'),
#  Text(0.14285714285714285, 0.3, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]\nclass = present'),
#  Text(0.2857142857142857, 0.3, 'Start <= 4.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = absent'),
#  Text(0.21428571428571427, 0.1, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = absent'),
#  Text(0.35714285714285715, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = present'),
#  Text(0.6428571428571429, 0.7, 'Start <= 12.5\ngini = 0.176\nsamples = 41\nvalue = [37, 4]\nclass = absent'),
#  Text(0.5, 0.5, 'Start <= 11.5\ngini = 0.444\nsamples = 9\nvalue = [6, 3]\nclass = absent'),
#  Text(0.42857142857142855, 0.3, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = absent'),
#  Text(0.5714285714285714, 0.3, 'Age <= 30.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = present'),
#  Text(0.5, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = absent'),
#  Text(0.6428571428571429, 0.1, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = present'),
#  Text(0.7857142857142857, 0.5, 'Age <= 154.0\ngini = 0.061\nsamples = 32\nvalue = [31, 1]\nclass = absent'),
#  Text(0.7142857142857143, 0.3, 'gini = 0.0\nsamples = 24\nvalue = [24, 0]\nclass = absent'),
#  Text(0.8571428571428571, 0.3, 'Age <= 157.5\ngini = 0.219\nsamples = 8\nvalue = [7, 1]\nclass = absent'),
#  Text(0.7857142857142857, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = present'),
#  Text(0.9285714285714286, 0.1, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = absent')]

# %%
plt.figure(figsize=(15,12))
tree.plot_tree(dtree)
# Out:
# [Text(0.39285714285714285, 0.9, 'X[2] <= 8.5\ngini = 0.392\nsamples = 56\nvalue = [41, 15]'),
#  Text(0.14285714285714285, 0.7, 'X[0] <= 11.5\ngini = 0.391\nsamples = 15\nvalue = [4, 11]'),
#  Text(0.07142857142857142, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.21428571428571427, 0.5, 'X[0] <= 130.5\ngini = 0.26\nsamples = 13\nvalue = [2, 11]'),
#  Text(0.14285714285714285, 0.3, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.2857142857142857, 0.3, 'X[2] <= 4.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.21428571428571427, 0.1, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.35714285714285715, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6428571428571429, 0.7, 'X[2] <= 12.5\ngini = 0.176\nsamples = 41\nvalue = [37, 4]'),
#  Text(0.5, 0.5, 'X[2] <= 11.5\ngini = 0.444\nsamples = 9\nvalue = [6, 3]'),
#  Text(0.42857142857142855, 0.3, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.5714285714285714, 0.3, 'X[0] <= 30.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.5, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6428571428571429, 0.1, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.7857142857142857, 0.5, 'X[0] <= 154.0\ngini = 0.061\nsamples = 32\nvalue = [31, 1]'),
#  Text(0.7142857142857143, 0.3, 'gini = 0.0\nsamples = 24\nvalue = [24, 0]'),
#  Text(0.8571428571428571, 0.3, 'X[0] <= 157.5\ngini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(0.7857142857142857, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9285714285714286, 0.1, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]')]
