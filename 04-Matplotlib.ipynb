# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np

# %%
x=np.linspace(0,5,11)
y=x**2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
# Functional
plt.plot(x,y)
# plt.show()

# %%
plt.plot(x,y,'r-')

# %%
plt.xlabel('X Label')
plt.ylabel('Y Label')
plt.title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r')
plt.subplot(1,2,2)
plt.plot(y,x,'b')

# %%
#OO
fig=plt.figure()

axes=fig.add_axes([0.1,0.1,0.8,0.8])

axes.plot(x,y)
axes.set_xlabel('X Label')
axes.set_ylabel('Y Label')
axes.set_title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %%
fig=plt.figure()
axes1=fig.add_axes([0.1,0.1,0.8,0.8])
axes2=fig.add_axes([0.2,0.5,0.4,0.3])

# %%
fig=plt.figure()
axes1=fig.add_axes([0.1,0.1,0.8,0.8])
axes2=fig.add_axes([0.5,0.1,0.4,0.3])

# %%
fig=plt.figure()
axes1=fig.add_axes([0.1,0.1,0.8,0.8])
axes2=fig.add_axes([0.5,0.1,0.4,0.3])

# %%
fig=plt.figure()
axes1=fig.add_axes([0.1,0.1,0.8,0.8])
axes2=fig.add_axes([0.4,0.2,0.4,0.3])

# %%
fig=plt.figure()
axes1=fig.add_axes([0.1,0.1,0.8,0.8])
axes2=fig.add_axes([0.2,0.5,0.4,0.3])

axes1.plot(x,y,'r')
axes1.set_title('Larger plot')

axes2.plot(y,x,'b')
axes2.set_title('SMALLER PLOT')
# Out:
# Text(0.5, 1.0, 'SMALLER PLOT')

# %%
fig=plt.figure()
axes1=fig.add_axes([0.1,0.1,0.8,0.8])
axes1.plot(x,y)

# %%
fig,axes=plt.subplots(nrows=3,ncols=3)
# axes.plot(x,y)
plt.tight_layout()

# %%
fig,axes=plt.subplots(nrows=3,ncols=3)
# axes.plot(x,y)

# %%
axes
# Out:
# array([[<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
fig,axes=plt.subplots(nrows=1,ncols=2)
for current_ax in axes:
    current_ax.plot(x,y)

# %%
fig,axes=plt.subplots(nrows=1,ncols=2)
axes[0].plot(x,y)
axes[0].set_title('First Plot')

axes[1].plot(y,x)
axes[1].set_title('Second Plot')
# Out:
# Text(0.5, 1.0, 'Second Plot')

# %%
fig=plt.figure(figsize=(8,2))
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %%
fig,axes=plt.subplots(nrows=2,ncols=1,figsize=(8,2))
axes[0].plot(x,y)
axes[1].plot(y,x)
plt.tight_layout()

# %%
fig

# %%
fig.savefig('my_pic.png')

# %%
fig=plt.figure()

ax=fig.add_axes([0,0,1,1])
ax.plot(x,y)
# ax.set_title('Title')
# ax.set_ylabel('Y')
# ax.set_xlabel('X')
ax.plot(y,x)

# %%
fig=plt.figure()

ax=fig.add_axes([0,0,1,1])

ax.plot(x,x**2,label='X Sqaured')

ax.plot(x,x**3,label='X Cubed')
ax.legend()

# %%
fig=plt.figure()

ax=fig.add_axes([0,0,1,1])

ax.plot(x,x**2,label='X Sqaured')

ax.plot(x,x**3,label='X Cubed')
ax.legend(loc=10)

# %%
fig=plt.figure()

ax=fig.add_axes([0,0,1,1])

ax.plot(x,x**2,label='X Sqaured')

ax.plot(x,x**3,label='X Cubed')
ax.legend(loc=(0.1,0.1))

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y,color='green')

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y,color='#FF8C00') # RGB Hex Code--> Google search

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y,color='magenta')

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y,color='brown',linewidth=3)

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y,color='brown',linewidth=3,alpha=0.5)

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y,color='brown',lw=3,alpha=0.5)

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y,color='brown',lw=3,linestyle='-.')

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y,color='brown',lw=3,linestyle=':')

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y,color='brown',lw=3,ls='-')

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
len(x)
# Out:
# 11

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y,color='brown',lw=0.5,ls=':',marker='*')

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y,color='brown',lw=1,ls='-',marker='o',markersize=4)

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y,color='brown',lw=1,ls='-',marker='o',markersize=4,markerfacecolor='blue',markeredgewidth=3,markeredgecolor='yellow')

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y,color='brown',lw=1,ls='--')

ax.set_xlim([0,1])
ax.set_ylim([0,2])
# Out:
# (0.0, 2.0)
